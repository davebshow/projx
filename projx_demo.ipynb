# %% [markdown]
# # ProjX - a query/schema manipulation language for NetworkX.

# %%
# %matplotlib inline

# %%
import networkx as nx
import projx as px
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = 14, 7

# %% [markdown]
# ## This is the starting state of the graph.

# %%
g = px.test_graph()
"""
def test_graph():
    g = nx.Graph([(1, 2), (1, 3), (2, 3),(3, 4), (4, 5), (5, 6),
                  (7, 3), (8, 5), (7, 2), (8, 4), (7, 4),
                  (9, 4), (9, 10), (11, 3)])
    g.node[1] = {'type': 'Person', 'name': 'davebshow'}
    g.node[2] = {'type':'Institution', 'name': 'western'}
    g.node[3] = {'type':'City', 'name': 'london'}
    g.node[4] = {'type':'Institution', 'name': 'the matrix'}
    g.node[5] = {'type':'City', 'name': 'toronto'}
    g.node[6] = {'type':'Person', 'name': 'gandalf'}
    g.node[7] = {'type':'Person', 'name': 'versae'}
    g.node[8] = {'type':'Person', 'name': 'kreeves'}
    g.node[9] = {'type':'Person', 'name': 'r2d2'}
    g.node[10] = {'type': 'City', 'name': 'alderon'}
    g.node[11] = {'type': 'Person', 'name': 'curly'}
    return g   
"""
px.draw_simple(g)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd0a92cb50>,
#   2: <matplotlib.text.Text at 0x7fcd0a92cf90>,
#   3: <matplotlib.text.Text at 0x7fcd0a938410>,
#   4: <matplotlib.text.Text at 0x7fcd0a938850>,
#   5: <matplotlib.text.Text at 0x7fcd0a938c90>,
#   6: <matplotlib.text.Text at 0x7fcd0a945110>,
#   7: <matplotlib.text.Text at 0x7fcd0a945550>,
#   8: <matplotlib.text.Text at 0x7fcd0a945990>,
#   9: <matplotlib.text.Text at 0x7fcd0a945dd0>,
#   10: <matplotlib.text.Text at 0x7fcd0a94e250>,
#   11: <matplotlib.text.Text at 0x7fcd0a94e690>})

# %% [markdown]
# ## Here's a little preview:

# %%
# Wrap the graph with ProjX
p = px.Projection(g)
# Watch this!
proj = p.execute('''
    MATCH          (p1:Person)-(i:Institution)-(c:City)-(p2:Person)
    TRANSFER_ATTRS (i)-(p1)
    TRANSFER_ATTRS (c)-(p2)
    TRANSFER       (c)-(i)
    PROJECT        (p1)-(i)-(p2)
''')
px.draw_simple(proj)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd0a81a750>,
#   6: <matplotlib.text.Text at 0x7fcd0a81ab90>,
#   7: <matplotlib.text.Text at 0x7fcd0a81afd0>,
#   8: <matplotlib.text.Text at 0x7fcd0a828450>,
#   9: <matplotlib.text.Text at 0x7fcd0a828890>,
#   11: <matplotlib.text.Text at 0x7fcd0a828cd0>})

# %% [markdown]
# The ProjX query language syntax is as follows:
# ----------------------------------------------
#
# Verbs:
# ======
# - "MATCH" Matches a pattern of nodes based on type.
# - "MATCH PARTIAL" Like "MATCH", but also matchs a partial pattern. Coming soon...
# - "TRANSFER" transfers the edges and attributes of nodes of one
#      type across a specified sequence of neighboring nodes
#      to nodes of another type.
# - "TRANSFER_ATTRS" Like "TRANSFER", but only transfers attributes.
# - "PROJECT" Projects a relationship between nodes of one
#     type across a specified sequence of neighboring nodes.
# - "RETURN" Specify table/graph and nodes to return. Coming soon...
#
# Patterns:
# =========
#
# Nodes:
# ------
# Nodes are represented using (). For the minimal syntax, the
# () contains at least a node type specification, this specification
# corresponds to the attribute set at init type_attr: (Type1).
# For longer queries over subgraphs, it is recommended to
# include an alias with the (): (t1:Type1). This allows for
# cleaner code and prevents errors when using complex pattern
# that repeat types.
# - (f:Foo)
# - (b:Bar)
#
# Edges:
# ------
# Currently, only simple undirected edges are permited. They are
# denoted with the hyphen -. Support for edge types and attrs are
# coming soon.
#
# Patterns:
# ---------
# A pattern is a combination of nodes and edges. It creates a
# "type sequence", or a set of criteria that determain a legal
# path during graph traversal based on node's type_attr. For
# example, if we want to locate all nodes with type_attr == 'Type1'
# that are connected to nodes with type_attr == 'Type2', the pattern
# would be specified as "(t1:Type1)-(t2:Type2)". A pattern can be as
# long as necessary, and can repeat elements. Note that the traversal
# does not permit cycles:
# - "(f1:Foo)-(b:Bar)-(f2:Foo)"
# - "(d:Dog)-(p1:Person)-(p2:Person)-(c:Cat)"
#
# Queries:
# ========
# ProjX queries combine a verb with a pattern to perform some kind
# of search or schema modification over the graph. If queries begin
# with a "MATCH" clause, they will project across only the matched
# subgraph, thus discarding all nodes that do not match. If queries
# begin with a different clause, they will still only be able to act
# upon the first matched pattern; however, they retain all other nodes
# not involved in the pattern regards of other operations.
#
# Matched subgraph queries:
# -------------------
# Matched subgraph queries must begin with a "MATCH" statement. This
# produces the subgraph upon which the rest of the verbs will
# operate. After a graph is match, other projections can be perfomed
# upon the resulting subgraph. For example, let's imagine we want to
# project a For example, let's imagine we want to project a social
# network of 'Person' nodes through their association with nodes of
# type 'Institution'. First we match the subgraph, and then make
# the projection:
#
# <b>
# '''<br>
# MATCH (p1:Person)-(i:Institution)-(p2:Person)<br>
# PROJECT (p1)-(i)-(p2)<br>
# '''
# </b>
# <br>
#
# In the above example it is important to note the mandatory use of
# the alias style node syntax. To go a step further, let's transfer the
# edges and atributes contained in nodes of type 'City' to neighboring
# nodes of type 'Person', and then project the same social network of
# 'Person' nodes through their association with nodes of type
# 'Institution'. The query is as follows:
#
# <b>
# '''<br>
# MATCH    (c:City)-(p1:Person)-(i:Institution)-(p2:Person)<br>
# TRANSFER (c)-(p1)<br>
# PROJECT  (p1)-(i)-(p2)<br>
# '''
# </b>
# <br>
#
# ^ In an undirected graph "TRANSFER (c)-(p1)" finds p2 as well.
#
# And we can keep making up examples:
#
# <b>
# '''<br>
# MATCH    (p1:Person)-(c:City)-(i:Institution)-(p2:Person)<br>
# TRANSFER (c)-(i)<br>
# '''
#
# <br>
# '''<br>
# MATCH          (p1:Person)-(i:Institution)-(c:City)-(p2:Person)<br>
# TRANSFER_ATTRS (i)-(p1)<br>
# TRANSFER_ATTRS (c)-(p2)<br>
# TRANSFER       (i)-(c)<br>
# PROJECT        (p1)-(i)-(p2)<br>
# '''
# ...
# </b>
# <br>
#
# CURRENTLY ProjX only allows ***1 match per query***! Also, in
# the future it will probably allow soft pattern matching to match
# partial patterns as well.
#
# Full graph queries:
# -----------------
# To perform an projection over the whole graph and return a modified
# copy, simply tell ProjX what you want to do by combining a verb and
# a simple pattern. Node Type aliases are not necessary for one-line
# queries UNLESS you are using the same node type multiple times in the
# pattern. For example, to transfer all the attributes of nodes of
# type 'Foo' to their neighboring nodes of type 'Bar' and delete the
# 'Foo' nodes we can say:
#
# <b>
# "TRANSFER (Foo)-(Bar)".
# </b>
# <br>
#
# We can also use a wildcard node type when we want a more flexible
# traversal. Let's project an association graph of people connected
# to other people through a node of any other type:
#
# <b>
# "PROJECT (p1:Person)-()-(p2:Person)".
# </b>
# <br>
#
# Here it is important to remember this projection will delete the
# wildcard nodes, but any other nodes that are not matched by this
# pattern remain in the graph. If you only want the returned graph
# to contain the 'Person' nodes, you will need to use a Multi-line
# query as defined in the following section. For a final example, let's
# "TRANSFER" 'Institution' attributes to nodes of type 'City', but only
# when they are connected through a node of type 'Person':
#
# <b>
# "TRANSFER (Institution)-(Person)-(City)"
# </b>
# <br>
#
# We can still write multi-line queries that act over the whole graph
# too.
#
# <b>
# """
# TRANSFER_ATTRS (i:Institution)-(p:Person)-(c:City)
# TRANSFER       (c)-(p)
# """
# </b>
# <br>
#
# And we can continue:
#
# <b>
# "TRANSFER (Foo)-(Bar)"
# ...
# </b>
# <br>
#
# Note that single line queries use the first and last specified
# nodes as the source and target of the operation.
#
# Predicates:
# ===========
# ProjX doesn't currently support predicates such as "AS", "WHERE",
# but it will soon.

# %% [markdown]
# ## Basic Idea - Use a Cypher style query to make a projection over a NetworkX graph

# %%
# Wrap the graph with ProjX
p = px.Projection(g)
# Minimal projection of a association graph.
proj = p.execute('''
    MATCH (p1:Person)-(wild:)-(p2:Person)
    PROJECT (p1)-(wild)-(p2)
''')
px.draw_simple(proj)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd0a76e590>,
#   6: <matplotlib.text.Text at 0x7fcd0a76e9d0>,
#   7: <matplotlib.text.Text at 0x7fcd0a76ee10>,
#   8: <matplotlib.text.Text at 0x7fcd0a779290>,
#   9: <matplotlib.text.Text at 0x7fcd0a7796d0>,
#   11: <matplotlib.text.Text at 0x7fcd0a779b10>})

# %%
# Projection of Person over Institution with City attribute transfered
# to all people living in a city that are connected to other people by an institution.
proj = p.execute('''
    MATCH    (c:City)-(p1:Person)-(Institution:)-(p2:Person)
    TRANSFER (c)-(p1)
    PROJECT  (p1)-(wild)-(p2)
''')
px.draw_simple(proj)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd08c47050>,
#   7: <matplotlib.text.Text at 0x7fcd08c478d0>,
#   8: <matplotlib.text.Text at 0x7fcd08cbcbd0>,
#   9: <matplotlib.text.Text at 0x7fcd08c47490>})

# %%
# Watch this.
proj = p.execute('''
    MATCH    (p:Person)-(i:Institution)-(c:City)-(p2:Person)
    TRANSFER (i)-(c)
''')
px.draw_simple(proj)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd08b99c50>,
#   3: <matplotlib.text.Text at 0x7fcd08ba60d0>,
#   5: <matplotlib.text.Text at 0x7fcd08ba6510>,
#   6: <matplotlib.text.Text at 0x7fcd08ba6950>,
#   7: <matplotlib.text.Text at 0x7fcd08ba6d90>,
#   8: <matplotlib.text.Text at 0x7fcd08bb1210>,
#   9: <matplotlib.text.Text at 0x7fcd08bb1650>,
#   11: <matplotlib.text.Text at 0x7fcd08bb1a90>})

# %%
# Now add a projection!
proj = p.execute('''
    MATCH    (p1:Person)-(c:City)-(i:Institution)-(p2:Person)
    TRANSFER (c)-(i)
    PROJECT  (p1)-(i)-(p2)
''')
px.draw_simple(proj)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd08a8e210>,
#   6: <matplotlib.text.Text at 0x7fcd08a8e650>,
#   7: <matplotlib.text.Text at 0x7fcd08a8ea90>,
#   8: <matplotlib.text.Text at 0x7fcd08a8eed0>,
#   9: <matplotlib.text.Text at 0x7fcd08a99350>,
#   11: <matplotlib.text.Text at 0x7fcd08a99790>})

# %%
# The coolest!
# Watch this.
proj = p.execute('''
    MATCH          (p1:Person)-(i:Institution)-(c:City)-(p2:Person)
    TRANSFER_ATTRS (i)-(p1)
    TRANSFER_ATTRS (c)-(p2)
    TRANSFER       (i)-(c)
    PROJECT        (p1)-(i)-(p2)
''')
px.draw_simple(proj)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd089ebcd0>,
#   6: <matplotlib.text.Text at 0x7fcd089f6150>,
#   7: <matplotlib.text.Text at 0x7fcd089f6590>,
#   8: <matplotlib.text.Text at 0x7fcd089f69d0>,
#   9: <matplotlib.text.Text at 0x7fcd089f6e10>,
#   11: <matplotlib.text.Text at 0x7fcd08a02290>})

# %% [markdown]
# #### Simple queries. These are mainly for clean up of many-partite graphs before projection.

# %% [markdown]
# ##### MATCH subgraphs.

# %% [markdown]
# ###### Simple subgraph matching using a "mode sequence", which limits a depth first traversal to walk only paths containing node types that match the sequence. For example, if we are interested in all of the paths between a person and a city by way of their publications, we could say "MATCH Person-Publication-City".

# %% [markdown]
# ###### A longer example: "MATCH Person-City-Institution-City-Person"

# %%
subgraph = p.execute("MATCH (p1:Person)-(c1:City)-(i:Institution)-(c:City)-(p2:Person)")
px.draw_simple(subgraph)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd088c95d0>,
#   3: <matplotlib.text.Text at 0x7fcd088c9a10>,
#   4: <matplotlib.text.Text at 0x7fcd088c9e50>,
#   5: <matplotlib.text.Text at 0x7fcd088d32d0>,
#   6: <matplotlib.text.Text at 0x7fcd088d3710>,
#   7: <matplotlib.text.Text at 0x7fcd088d3b50>,
#   8: <matplotlib.text.Text at 0x7fcd088d3f90>,
#   11: <matplotlib.text.Text at 0x7fcd088e0410>})

# %% [markdown]
# ###### What if we want one of the types in the type sequence to be a wild card (accepting any value) - just leave it blank. In this case we will find all people connected by a path with any other node type. Query "MATCH (Person)-()-(Person)"

# %%
subgraph = p.execute("MATCH (p1:Person)-(wild:)-(p2:Person)")
px.draw_simple(subgraph)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd0882db50>,
#   2: <matplotlib.text.Text at 0x7fcd0882df90>,
#   3: <matplotlib.text.Text at 0x7fcd08839410>,
#   4: <matplotlib.text.Text at 0x7fcd08839850>,
#   5: <matplotlib.text.Text at 0x7fcd08839c90>,
#   6: <matplotlib.text.Text at 0x7fcd087c4110>,
#   7: <matplotlib.text.Text at 0x7fcd087c4550>,
#   8: <matplotlib.text.Text at 0x7fcd087c4990>,
#   9: <matplotlib.text.Text at 0x7fcd087c4dd0>,
#   11: <matplotlib.text.Text at 0x7fcd087d1250>})

# %% [markdown]
# ##### TRANSFER_ATTRS node attributesfrom nodes of one type onto their neighbors of another type. Once again uses a pattern.

# %% [markdown]
# ###### Let's say we want to get rid of nodes of type City, and transfer their edges and attributes on any Person they are connected to. Query: "TRANSFER City-Person"

# %%
subgraph = p.execute("TRANSFER (c:City)-(p:Person)")
px.draw_simple(subgraph)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd087265d0>,
#   2: <matplotlib.text.Text at 0x7fcd08726a10>,
#   4: <matplotlib.text.Text at 0x7fcd08726e50>,
#   6: <matplotlib.text.Text at 0x7fcd087312d0>,
#   7: <matplotlib.text.Text at 0x7fcd08731710>,
#   8: <matplotlib.text.Text at 0x7fcd08731b50>,
#   9: <matplotlib.text.Text at 0x7fcd08731f90>,
#   11: <matplotlib.text.Text at 0x7fcd0873e410>})

# %% [markdown]
# ###### Or transfer the City node's edges and attributes onto any node connected with it. Query: "TRANSFER (City)-()"

# %%
subgraph = p.execute("TRANSFER (City)-()")
px.draw_simple(subgraph)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd08613390>,
#   2: <matplotlib.text.Text at 0x7fcd086137d0>,
#   4: <matplotlib.text.Text at 0x7fcd08613c10>,
#   6: <matplotlib.text.Text at 0x7fcd08620090>,
#   7: <matplotlib.text.Text at 0x7fcd086204d0>,
#   8: <matplotlib.text.Text at 0x7fcd08620910>,
#   9: <matplotlib.text.Text at 0x7fcd08620d50>,
#   11: <matplotlib.text.Text at 0x7fcd0862c1d0>})

# %%
subgraph = p.execute("TRANSFER (City)-()")
px.draw_simple(subgraph)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd0813c350>,
#   2: <matplotlib.text.Text at 0x7fcd0813c790>,
#   4: <matplotlib.text.Text at 0x7fcd0813cbd0>,
#   6: <matplotlib.text.Text at 0x7fcd0814c050>,
#   7: <matplotlib.text.Text at 0x7fcd0814c490>,
#   8: <matplotlib.text.Text at 0x7fcd0814c8d0>,
#   9: <matplotlib.text.Text at 0x7fcd0814cd10>,
#   11: <matplotlib.text.Text at 0x7fcd08158190>})

# %% [markdown]
# ##### TRANSFER acts just like TRANSFER_ATTRS, but it also transfers edges.

# %%
subgraph = p.execute("TRANSFER (Institution)-(City)")
px.draw_simple(subgraph)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd085044d0>,
#   3: <matplotlib.text.Text at 0x7fcd08504910>,
#   5: <matplotlib.text.Text at 0x7fcd08504d50>,
#   6: <matplotlib.text.Text at 0x7fcd0850f1d0>,
#   7: <matplotlib.text.Text at 0x7fcd0850f610>,
#   8: <matplotlib.text.Text at 0x7fcd0850fa50>,
#   9: <matplotlib.text.Text at 0x7fcd0850fe90>,
#   10: <matplotlib.text.Text at 0x7fcd0851c310>,
#   11: <matplotlib.text.Text at 0x7fcd0851c750>})

# %%
subgraph = p.execute("TRANSFER (City)-()")
px.draw_simple(subgraph)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd08472d10>,
#   2: <matplotlib.text.Text at 0x7fcd0847f190>,
#   4: <matplotlib.text.Text at 0x7fcd0847f5d0>,
#   6: <matplotlib.text.Text at 0x7fcd0847fa10>,
#   7: <matplotlib.text.Text at 0x7fcd0847fe50>,
#   8: <matplotlib.text.Text at 0x7fcd0840a2d0>,
#   9: <matplotlib.text.Text at 0x7fcd0840a710>,
#   11: <matplotlib.text.Text at 0x7fcd0840ab50>})

# %% [markdown]
# ##### Finally, we can PROJECT across as many modes as we want.

# %% [markdown]
# ###### How about projection a association graph with people that share association with any other node type? Query: "PROJECT (Person)-()-(Person)"

# %%
subgraph = p.execute("PROJECT (p1:Person)-()-(p2:Person)")
px.draw_simple(subgraph)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd083605d0>,
#   6: <matplotlib.text.Text at 0x7fcd08360a10>,
#   7: <matplotlib.text.Text at 0x7fcd08360e50>,
#   8: <matplotlib.text.Text at 0x7fcd0836d2d0>,
#   9: <matplotlib.text.Text at 0x7fcd0836d710>,
#   10: <matplotlib.text.Text at 0x7fcd0836db50>,
#   11: <matplotlib.text.Text at 0x7fcd0836df90>})

# %% [markdown]
# ###### A longer projection. Note that only matching paths generate edges: "PROJECT Person-City-Institution-City-Person".

# %%
subgraph = p.execute("PROJECT (p1:Person)-(City)-(Institution)-(p2:Person)")
px.draw_simple(subgraph)
# Out:
# (None,
#  {1: <matplotlib.text.Text at 0x7fcd08252410>,
#   6: <matplotlib.text.Text at 0x7fcd08252850>,
#   7: <matplotlib.text.Text at 0x7fcd08252c90>,
#   8: <matplotlib.text.Text at 0x7fcd0825d110>,
#   9: <matplotlib.text.Text at 0x7fcd0825d550>,
#   10: <matplotlib.text.Text at 0x7fcd0825d990>,
#   11: <matplotlib.text.Text at 0x7fcd0825ddd0>})

# %% [markdown]
# ##### !!!A lack of nodes matching the specified type sequence throws an exception!!!

# %%
subgraph = p.execute('PROJECT (Dog)-(Cat)-(Dog)')
print(subgraph.nodes(), subgraph.edges())
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-b5846168fd3f> in <module>()
# ----> 1 subgraph = p.execute('PROJECT (Dog)-(Cat)-(Dog)')
#       2 print(subgraph.nodes(), subgraph.edges())
#
# /home/davebshow/git/projx/projx/projection.py in execute(self, query)
#     265         pattern = clauses[0]['pattern']
#     266         mp = _MatchPattern(pattern)  # Fix pattern processor
# --> 267         paths = self._match(mp)
#     268         if verb == 'match':
#     269             graph = self.match(paths)
#
# /home/davebshow/git/projx/projx/projection.py in _match(self, pattern)
#     331         paths = list(chain.from_iterable(path_list))
#     332         if not paths:
# --> 333             raise Exception('There are no nodes matching '
#     334                             'the given type sequence. Check for '
#     335                             'spelling errors and syntax')
#
# Exception: There are no nodes matching the given type sequence. Check for spelling errors and syntax

# %% [markdown]
# ##### !!!Query must begin with valid verb!!!

# %%
subgraph = p.execute("SELECT (City)-(Institution)")
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-22-d63a62979dff> in <module>()
# ----> 1 subgraph = p.execute("SELECT (City)-(Institution)")
#
# /home/davebshow/git/projx/projx/projection.py in execute(self, query)
#     261                   schema modfications.
#     262         """
# --> 263         clauses = self.parser.parseString(query)
#     264         verb = clauses[0]['verb']
#     265         pattern = clauses[0]['pattern']
#
# /home/davebshow/.virtualenvs/scientific/local/lib/python2.7/site-packages/pyparsing.pyc in parseString(self, instring, parseAll)
#    1109             else:
#    1110                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1111                 raise exc
#    1112         else:
#    1113             return tokens
#
# ParseException: Expected "MATCH" (at char 0), (line:1, col:1)

# %% [markdown]
# ##### !!!Patterns need the Cypherish parenthesis!!!

# %%
subgraph = p.execute('PROJECT Person-City')
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-23-d77f6cfdeaf4> in <module>()
# ----> 1 subgraph = p.execute('PROJECT Person-City')
#
# /home/davebshow/git/projx/projx/projection.py in execute(self, query)
#     261                   schema modfications.
#     262         """
# --> 263         clauses = self.parser.parseString(query)
#     264         verb = clauses[0]['verb']
#     265         pattern = clauses[0]['pattern']
#
# /home/davebshow/.virtualenvs/scientific/local/lib/python2.7/site-packages/pyparsing.pyc in parseString(self, instring, parseAll)
#    1109             else:
#    1110                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1111                 raise exc
#    1112         else:
#    1113             return tokens
#
# ParseException: Expected "(" (at char 8), (line:1, col:9)

# %% [markdown]
# ##### !!!Start node required!!!

# %%
subgraph = p.execute('MATCH ()-(City)')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-24-6696b5c1f3f1> in <module>()
# ----> 1 subgraph = p.execute('MATCH ()-(City)')
#
# /home/davebshow/git/projx/projx/projection.py in execute(self, query)
#     265         pattern = clauses[0]['pattern']
#     266         mp = _MatchPattern(pattern)  # Fix pattern processor
# --> 267         paths = self._match(mp)
#     268         if verb == 'match':
#     269             graph = self.match(paths)
#
# /home/davebshow/git/projx/projx/projection.py in _match(self, pattern)
#     331         paths = list(chain.from_iterable(path_list))
#     332         if not paths:
# --> 333             raise Exception('There are no nodes matching '
#     334                             'the given type sequence. Check for '
#     335                             'spelling errors and syntax')
#
# Exception: There are no nodes matching the given type sequence. Check for spelling errors and syntax
